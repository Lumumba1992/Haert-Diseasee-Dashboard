# %% [markdown]
# <div style='text-align:center;'>
#   <img src="CDAM.PNG" width="1200">
# </div>

# %% [markdown]
# <div style="text-align: center; font-weight: bold; font-size: 22px; color: #1a1a1a;">
#   <div style="color: #0B5394; font-size: 38px;">CENTER FOR DATA ANALYTICS AND MODELLING (CDAM)</div>
#   <div style="color: #38761D; font-size: 24px;">DATA CLEANING AND MANIPULATION</div>
#   <br>
#   <div style="color: #CC0000; font-size: 22px;">FACILITATOR:</div>
#   <div style="color: #000000; font-size: 20px;">VICTOR WANDERA LUMUMBA</div>
#   <div style="color: #3D85C6; font-size: 20px;">Chuka University, Kenya</div>
#   <br>
#   <div style="color: #6AA84F; font-size: 18px;">Date:</div>
#   <div style="color: #351C75; font-size: 18px;">February 16, 2026</div>
# </div>

# %% [markdown]
# ## **DATA IMPORTATION, CLEANING, WRANGLING AND MANIPULATION**

# %% [markdown]
# #### **Objectives**
# - Import and Inspect Real World Data Set
# - Identify and Handle Missing values, Duplicates and Outliers
# - Subset and Filter Rows Based on Some Conditions
# - Selecting Specific Columns
# - Data Engineering (Creating a Categorical Variables From Continous Variables)
# - Generate Comprehensive Descriptive Statistics

# %% [markdown]
# ## **1. Data Importation**
# **Why Does this Matter**
# - CSV File is a Universal Standard Tabular Data Structure
# - Pandas Function read_csv() makes it possible to read csv File from the Local Directory
# - The Function read_csv() helps prevent downstream errors.

# %% [markdown]
# ### **Install the Following Libraries if not Installed**

# %%
# pip install pandas
# pip install numpy
# pip install seaborn
# pip install matplotlib

# %% [markdown]
# ### **Load the Required Libraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# #### **Read the Dataset**

# %%
df = pd.read_csv("GSSsubset1.csv")
df.head()
# Out:
#    id     sex       degree    income        marital  age  height  weight  \
# 0   1    MALE  HIGH SCHOOL  26722.56  NEVER MARRIED   18    73.2    86.3
# 1   2    MALE          NaN  36544.91        MARRIED   35    69.9    95.3
# 2   3  FEMALE  HIGH SCHOOL  59587.14       DIVORCED   28    70.1    60.9
# 3   4  FEMALE     GRADUATE       NaN        MARRIED   43    61.9    76.0
# 4   5    MALE  HIGH SCHOOL  48899.47        MARRIED   48    65.8    58.9
#
#    hrswrk
# 0    35.0
# 1    47.0
# 2    16.0
# 3    44.0
# 4    44.0

# %% [markdown]
# ### **General Inspection of the Data**

# %%
### Column Names
print(f"Columns:{df.columns.tolist()}")
# Out:
# Columns:['id', 'sex', 'degree', 'income', 'marital', 'age', 'height', 'weight', 'hrswrk']

# %%
### Dimension of the Data
print(f"Shape: {df.shape}")
# Out:
# Shape: (3000, 9)

# %%
#### Variable Types
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   object
#  2   degree   2942 non-null   object
#  3   income   2767 non-null   float64
#  4   marital  2934 non-null   object
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   2879 non-null   float64
#  8   hrswrk   2933 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 211.1+ KB

# %% [markdown]
# ### **General Descriptive Statistics**

# %%
dir(df)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
df.describe()
# Out:
#                 id         income          age       height       weight  \
# count  3000.000000    2767.000000  3000.000000  3000.000000  2879.000000
# mean   1500.500000   63871.815790    42.078000    67.400500    76.389232
# std     866.169729   51634.075898    13.314316     3.641297    14.584233
# min       1.000000    3720.040000    18.000000    58.100000    45.000000
# 25%     750.750000   31989.025000    33.000000    64.600000    65.800000
# 50%    1500.500000   49586.540000    42.000000    67.200000    75.700000
# 75%    2250.250000   78986.595000    51.000000    70.100000    85.700000
# max    3000.000000  609741.180000    80.000000    78.600000   120.000000
#
#             hrswrk
# count  2933.000000
# mean     39.778043
# std      12.594723
# min       0.000000
# 25%      34.000000
# 50%      41.000000
# 75%      48.000000
# max      79.000000

# %%
df.drop(columns = ["id"]).describe()
# Out:
#               income          age       height       weight       hrswrk
# count    2767.000000  3000.000000  3000.000000  2879.000000  2933.000000
# mean    63871.815790    42.078000    67.400500    76.389232    39.778043
# std     51634.075898    13.314316     3.641297    14.584233    12.594723
# min      3720.040000    18.000000    58.100000    45.000000     0.000000
# 25%     31989.025000    33.000000    64.600000    65.800000    34.000000
# 50%     49586.540000    42.000000    67.200000    75.700000    41.000000
# 75%     78986.595000    51.000000    70.100000    85.700000    48.000000
# max    609741.180000    80.000000    78.600000   120.000000    79.000000

# %% [markdown]
# ### **Frequencies for Categorical Variables**

# %%
print("Educational Level Distribution")
df['degree'].value_counts()
# Out:
# Educational Level Distribution
# degree
# HIGH SCHOOL       1094
# LT HIGH SCHOOL     583
# BACHELOR           566
# JUNIOR COLLEGE     465
# GRADUATE           234
# Name: count, dtype: int64

# %%
print("Marital Status Distribution")
df['marital'].value_counts()
# Out:
# Marital Status Distribution
# marital
# MARRIED          1518
# NEVER MARRIED     691
# DIVORCED          382
# WIDOWED           227
# SEPARATED         116
# Name: count, dtype: int64

# %%
print("Gender Distribution")
df['sex'].value_counts()
# Out:
# Gender Distribution
# sex
# FEMALE    1563
# MALE      1437
# Name: count, dtype: int64

# %% [markdown]
# ### **3. DATA CLEANING**

# %% [markdown]
# #### **3.1. Handling Missing Values**

# %%
#### Check the Presence of Missing Values
print("The Total Number of Missing Values per Variable")
print(df.isna().sum())
# Out:
# The Total Number of Missing Values per Variable
# id           0
# sex          0
# degree      58
# income     233
# marital     66
# age          0
# height       0
# weight     121
# hrswrk      67
# dtype: int64

# %%
### Present the Missing Values as Percentage of Total Data Points
print("Percentages of Missing Values")
Missing_value = df.isna().mean().round(4)*100
Missing_value
# Out:
# Percentages of Missing Values
# id         0.00
# sex        0.00
# degree     1.93
# income     7.77
# marital    2.20
# age        0.00
# height     0.00
# weight     4.03
# hrswrk     2.23
# dtype: float64

# %% [markdown]
# #### **Methods of Handling Missing Values**
# - Complete Cases Analysis - Commonly used but risky
# - Mean Imputation - For Symmetric Distributed Data
# - Median Imputation - For Skewed Data (skewed left or right)
# - Model Imputation - For Categorical Variables

# %% [markdown]
# #### **Complete Cases Analysis**

# %%
df_drop_all = df.dropna()
print(df_drop_all.isna().sum())
# Out:
# id         0
# sex        0
# degree     0
# income     0
# marital    0
# age        0
# height     0
# weight     0
# hrswrk     0
# dtype: int64

# %%
df_drop_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2503 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       2503 non-null   int64
#  1   sex      2503 non-null   object
#  2   degree   2503 non-null   object
#  3   income   2503 non-null   float64
#  4   marital  2503 non-null   object
#  5   age      2503 non-null   int64
#  6   height   2503 non-null   float64
#  7   weight   2503 non-null   float64
#  8   hrswrk   2503 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 195.5+ KB

# %% [markdown]
# ### **Imputation Approach**
# #### **Mean Imputation**

# %%
df.isna().sum()
# Out:
# id           0
# sex          0
# degree      58
# income     233
# marital     66
# age          0
# height       0
# weight     121
# hrswrk      67
# dtype: int64

# %%
## Identify the Numeric Columns
numeric_cols = df.select_dtypes(include = 'number').columns

## Find the Median and Impute the Missing Values for the Numeric Columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

## Find the Mean and Impute the Missing Values for the Numeric Columns
# df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# %% [markdown]
# ### **Confirm the Imputation of Missing Values**

# %%
df.isna().sum()
# Out:
# id          0
# sex         0
# degree     58
# income      0
# marital    66
# age         0
# height      0
# weight      0
# hrswrk      0
# dtype: int64

# %% [markdown]
# #### **Mode Imputation for the Missing values**

# %%
cat_cols = df.select_dtypes(include = ['object','category']).columns
for col in cat_cols:
    mode_val = df[col].mode()
    if not mode_val.empty:
        df[col] = df[col].fillna(mode_val[0])

# %%
df.isna().sum()
# Out:
# id         0
# sex        0
# degree     0
# income     0
# marital    0
# age        0
# height     0
# weight     0
# hrswrk     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   object
#  2   degree   3000 non-null   object
#  3   income   3000 non-null   float64
#  4   marital  3000 non-null   object
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   3000 non-null   float64
#  8   hrswrk   3000 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 211.1+ KB

# %% [markdown]
# ### **Data Cleaning - Handling Duplicates**

# %%
dup_rows = df.duplicated().sum()
print(dup_rows)
# Out:
# 0

# %% [markdown]
# #### **Drop Duplicated Rows if Available**

# %%
df_clean = df.drop_duplicates()
df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       3000 non-null   int64
#  1   sex      3000 non-null   object
#  2   degree   3000 non-null   object
#  3   income   3000 non-null   float64
#  4   marital  3000 non-null   object
#  5   age      3000 non-null   int64
#  6   height   3000 non-null   float64
#  7   weight   3000 non-null   float64
#  8   hrswrk   3000 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 211.1+ KB

# %% [markdown]
# ### **Outliers Handling**

# %%
### Identify Numeric Columns (float and int)
numeric_cols = df.select_dtypes(include = ['float64','int64']).columns
for col in numeric_cols:
     Q1 = df[col].quantile(0.25)
     Q3 = df[col].quantile(0.75)
     IQR = Q3 - Q1
     lower_bound = Q1 - 1.5 * IQR
     upper_bound = Q3 + 1.5 * IQR

     outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
     #print(outliers)
     print(f"Columns '{col}': {len(outliers)} Outliers")
# Out:
# Columns 'id': 0 Outliers
# Columns 'income': 201 Outliers
# Columns 'age': 10 Outliers
# Columns 'height': 2 Outliers
# Columns 'weight': 32 Outliers
# Columns 'hrswrk': 155 Outliers

# %%
numeric_cols = ['income', 'height', 'weight', 'hrswrk']
outlier_ids = {}
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    # store IDs (assuming 'id' column exists)
    outlier_ids[col] = outliers['id'].tolist()

    print(f"Column '{col}': {len(outliers)} outliers")
    print(outliers['id'].tolist())
    print("-"*50)
# Out:
# Column 'income': 201 outliers
# ...

# %%
df.head(20)
# Out:
#     id     sex          degree     income        marital  age  height  weight  \
# 0    1    MALE     HIGH SCHOOL   26722.56  NEVER MARRIED   18    73.2    86.3
# 1    2    MALE     HIGH SCHOOL   36544.91        MARRIED   35    69.9    95.3
# 2    3  FEMALE     HIGH SCHOOL   59587.14       DIVORCED   28    70.1    60.9
# 3    4  FEMALE        GRADUATE   49586.54        MARRIED   43    61.9    76.0
# 4    5    MALE     HIGH SCHOOL   48899.47        MARRIED   48    65.8    58.9
# 5    6  FEMALE     HIGH SCHOOL   47790.38        MARRIED   43    60.7    68.4
# 6    7  FEMALE        BACHELOR  102903.23        MARRIED   42    66.5    66.7
# 7    8    MALE     HIGH SCHOOL   36707.09  NEVER MARRIED   52    65.9    76.8
# 8    9  FEMALE        BACHELOR   48404.51        MARRIED   35    66.8    94.6
# 9   10    MALE     HIGH SCHOOL   29044.70  NEVER MARRIED   18    69.3    85.2
# 10  11  FEMALE        GRADUATE  419380.86      SEPARATED   58    62.4    64.8
# ...

# %% [markdown]
# ### **Capping the Outliers**

# %%
numeric_cols = df.select_dtypes(include = ['float64','int64']).columns
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    
    IQR = Q3 - Q1
    
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Cap the Outliers
    df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])
    df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])

# %%
numeric_cols = df.select_dtypes(include = ['float64','int64']).columns
for col in numeric_cols:
     Q1 = df[col].quantile(0.25)
     Q3 = df[col].quantile(0.75)
     IQR = Q3 - Q1
     lower_bound = Q1 - 1.5 * IQR
     upper_bound = Q3 + 1.5 * IQR

     outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
     #print(outliers)
     print(f"Columns '{col}': {len(outliers)} Outliers")
# Out:
# Columns 'id': 0 Outliers
# Columns 'income': 0 Outliers
# Columns 'age': 0 Outliers
# Columns 'height': 0 Outliers
# Columns 'weight': 0 Outliers
# Columns 'hrswrk': 0 Outliers

# %% [markdown]
# ### **SAVE THE CLEAN DATA**

# %%
df.to_csv("Clean_GSSsubset.csv")

# %% [markdown]
# ## **DATA MANIPULATION**
# - Filtering (Rows Manipulation-subsetting rows)
# - Selecting (Columns Selection)
# - groupby
# - Aggregating and Summarizing
# - Combined Selection and Filtering

# %% [markdown]
# #### **Filtering**

# %%
df.head()
# Out:
#     id     sex       degree    income        marital   age  height  weight  \
# 0  1.0    MALE  HIGH SCHOOL  26722.56  NEVER MARRIED  18.0    73.2    86.3
# 1  2.0    MALE  HIGH SCHOOL  36544.91        MARRIED  35.0    69.9    95.3
# 2  3.0  FEMALE  HIGH SCHOOL  59587.14       DIVORCED  28.0    70.1    60.9
# 3  4.0  FEMALE     GRADUATE  49586.54        MARRIED  43.0    61.9    76.0
# 4  5.0    MALE  HIGH SCHOOL  48899.47        MARRIED  48.0    65.8    58.9
#
#    hrswrk
# 0    35.0
# 1    47.0
# 2    16.0
# 3    44.0
# 4    44.0

# %% [markdown]
# #### **Filter to have Male Participants Only**

# %%
male = df[df['sex'] =='MALE']
male.head()
# Out:
#      id   sex       degree    income        marital   age  height  weight  \
# 0   1.0  MALE  HIGH SCHOOL  26722.56  NEVER MARRIED  18.0    73.2    86.3
# 1   2.0  MALE  HIGH SCHOOL  36544.91        MARRIED  35.0    69.9    95.3
# 4   5.0  MALE  HIGH SCHOOL  48899.47        MARRIED  48.0    65.8    58.9
# 7   8.0  MALE  HIGH SCHOOL  36707.09  NEVER MARRIED  52.0    65.9    76.8
# 9  10.0  MALE  HIGH SCHOOL  29044.70  NEVER MARRIED  18.0    69.3    85.2
#
#    hrswrk
# 0    35.0
# 1    47.0
# 4    44.0
# 7    48.0
# 9    41.0

# %% [markdown]
# #### **Multiple Filtering**

# %%
subset = df[(df['sex'] == 'FEMALE') &
    (df['age'] > 35) &
    (df['marital'] == 'MARRIED')]
subset.head()
# Out:
#       id     sex       degree     income  marital   age  height  weight  \
# 3    4.0  FEMALE     GRADUATE   49586.54  MARRIED  43.0    61.9    76.0
# 5    6.0  FEMALE  HIGH SCHOOL   47790.38  MARRIED  43.0    60.7    68.4
# 6    7.0  FEMALE     BACHELOR  102903.23  MARRIED  42.0    66.5    66.7
# 14  15.0  FEMALE     GRADUATE  114886.28  MARRIED  40.0    64.1    75.5
# 15  16.0  FEMALE     BACHELOR   59232.59  MARRIED  51.0    62.9    72.9
#
#     hrswrk
# 3     44.0
# 5     46.0
# 6     51.0
# 14    42.0
# 15    20.0

# %% [markdown]
# #### **OR Condition**

# %%
high_educ = df[(df['degree'] == "BACHELOR") | (df['degree'] == "GRADUATE")]
high_educ.head()
# Out:
#       id     sex    degree       income    marital   age  height  weight  \
# 3    4.0  FEMALE  GRADUATE   49586.5400    MARRIED  43.0    61.9    76.0
# 6    7.0  FEMALE  BACHELOR  102903.2300    MARRIED  42.0    66.5    66.7
# 8    9.0  FEMALE  BACHELOR   48404.5100    MARRIED  35.0    66.8    94.6
# 10  11.0  FEMALE  GRADUATE  138753.5975  SEPARATED  58.0    62.4    64.8
# 14  15.0  FEMALE  GRADUATE  114886.2800    MARRIED  40.0    64.1    75.5
#
#     hrswrk
# 3     44.0
# 6     51.0
# 8     28.0
# 10    31.0
# 14    42.0

# %%
high_educ_married = df[(df['degree'] == "GRADUATE") | (df['degree'] == "BACHELOR")]
high_educ_married.head()
# Out:
#       id     sex    degree       income    marital   age  height  weight  \
# 3    4.0  FEMALE  GRADUATE   49586.5400    MARRIED  43.0    61.9    76.0
# 6    7.0  FEMALE  BACHELOR  102903.2300    MARRIED  42.0    66.5    66.7
# 8    9.0  FEMALE  BACHELOR   48404.5100    MARRIED  35.0    66.8    94.6
# 10  11.0  FEMALE  GRADUATE  138753.5975  SEPARATED  58.0    62.4    64.8
# 14  15.0  FEMALE  GRADUATE  114886.2800    MARRIED  40.0    64.1    75.5
#
#     hrswrk
# 3     44.0
# 6     51.0
# 8     28.0
# 10    31.0
# 14    42.0

# %% [markdown]
# #### **Selecting Columns**

# %%
### Select Single Column (Income Column)
income_column = df['income']
income_column.head()
# Out:
# 0    26722.56
# 1    36544.91
# 2    59587.14
# 3    49586.54
# 4    48899.47
# Name: income, dtype: float64

# %%
### Select Multiplee Columbs
cols = ['sex','age','income', 'marital','degree']
selected_columns = df[cols]
selected_columns.head()
# Out:
#       sex   age    income        marital       degree
# 0    MALE  18.0  26722.56  NEVER MARRIED  HIGH SCHOOL
# 1    MALE  35.0  36544.91        MARRIED  HIGH SCHOOL
# 2  FEMALE  28.0  59587.14       DIVORCED  HIGH SCHOOL
# 3  FEMALE  43.0  49586.54        MARRIED     GRADUATE
# 4    MALE  48.0  48899.47        MARRIED  HIGH SCHOOL

# %% [markdown]
# ### **Dropping of Columns**

# %%
dropped_columns = df.drop(columns = ['id', 'height'])
dropped_columns.head()
# Out:
#       sex       degree    income        marital   age  weight  hrswrk
# 0    MALE  HIGH SCHOOL  26722.56  NEVER MARRIED  18.0    86.3    35.0
# 1    MALE  HIGH SCHOOL  36544.91        MARRIED  35.0    95.3    47.0
# 2  FEMALE  HIGH SCHOOL  59587.14       DIVORCED  28.0    60.9    16.0
# 3  FEMALE     GRADUATE  49586.54        MARRIED  43.0    76.0    44.0
# 4    MALE  HIGH SCHOOL  48899.47        MARRIED  48.0    58.9    44.0

# %%
df.head()
# Out:
#     id     sex       degree    income        marital   age  height  weight  \
# 0  1.0    MALE  HIGH SCHOOL  26722.56  NEVER MARRIED  18.0    73.2    86.3
# 1  2.0    MALE  HIGH SCHOOL  36544.91        MARRIED  35.0    69.9    95.3
# 2  3.0  FEMALE  HIGH SCHOOL  59587.14       DIVORCED  28.0    70.1    60.9
# 3  4.0  FEMALE     GRADUATE  49586.54        MARRIED  43.0    61.9    76.0
# 4  5.0    MALE  HIGH SCHOOL  48899.47        MARRIED  48.0    65.8    58.9
#
#    hrswrk
# 0    35.0
# 1    47.0
# 2    16.0
# 3    44.0
# 4    44.0

# %% [markdown]
# ### **Grouping and Summarizing**
# * Spliting data by categories
# * Essential for Comparative Analysis (e.g income by gender, or degree)
# * Work with single of multiple columns
# * Suppprts aggregation functions: mean(), median(), count(), std()

# %%
print("="*60)
print("GROUPING BY $ AGGREGATION")
print("="*60)

# Groupe Income by Education Level
print("Mean Income by Educational Level")
income_by_educ = df.groupby('degree')['income'].mean().sort_values(ascending = False)
income_by_educ
# Out:
# ...
# GROUPING BY $ AGGREGATION
# ...
# Mean Income by Educational Level
# degree
# GRADUATE          101312.290983
# BACHELOR           79394.490040
# JUNIOR COLLEGE     63991.209984
# HIGH SCHOOL        50326.169965
# LT HIGH SCHOOL     33619.183349
# Name: income, dtype: float64

# %% [markdown]
# #### **Groupe Income by Marital Status**

# %%
print("="*60)
print("GROUPING BY $ AGGREGATION")
print("="*60)

# Groupe Income by Education Level
print("Mean Income by Marital Status")
income_by_marital = df.groupby('marital')['income'].mean().sort_values(ascending = False)
income_by_marital
# Out:
# ...
# GROUPING BY $ AGGREGATION
# ...
# Mean Income by Marital Status
# marital
# MARRIED          62940.739291
# WIDOWED          59930.869152
# SEPARATED        58308.433211
# DIVORCED         56700.688233
# NEVER MARRIED    49566.023582
# Name: income, dtype: float64

# %%
print("="*60)
print("GROUPING BY $ AGGREGATION")
print("="*60)

# Groupe Income by Education Level
print("Mean Income by Gender")
income_by_gender = df.groupby('sex')['income'].mean().sort_values(ascending = False)
income_by_gender
# Out:
# ...
# GROUPING BY $ AGGREGATION
# ...
# Mean Income by Gender
# sex
# MALE      62533.651788
# FEMALE    55096.061528
# Name: income, dtype: float64

# %%
prop_f_m = (55096.061528/62533.651788)*100
prop_f_m
# Out:
# 88.10625951413371

# %% [markdown]
# #### **Frequency Distribution for Categorical Variables**

# %%
print("Count by Marital Status")
marital_count = df['marital'].value_counts()
marital_count
# Out:
# Count by Marital Status
# marital
# MARRIED          1584
# NEVER MARRIED     691
# DIVORCED          382
# WIDOWED           227
# SEPARATED         116
# Name: count, dtype: int64

# %% [markdown]
# ### **Multiple Grouping by**

# %%
print("Mean Income by Gender AND Marital Status")
multiple_grouping = df.groupby(['sex','marital'])['income'].mean()
multiple_grouping
# Out:
# Mean Income by Gender AND Marital Status
# sex     marital
# FEMALE  DIVORCED         51329.793354
#         MARRIED          58622.129444
#         NEVER MARRIED    48763.820201
#         SEPARATED        56198.865542
#         WIDOWED          54918.039512
# MALE    DIVORCED         62541.169549
#         MARRIED          67658.692190
#         NEVER MARRIED    50384.646330
#         SEPARATED        60568.684286
#         WIDOWED          66412.103434
# Name: income, dtype: float64

# %% [markdown]
# #### **Unstack the Table**

# %%
multiple_grouping = df.groupby(['sex','marital'])['income'].mean().unstack()
multiple_grouping
# Out:
# marital      DIVORCED       MARRIED  NEVER MARRIED     SEPARATED       WIDOWED
# sex
# FEMALE   51329.793354  58622.129444   48763.820201  56198.865542  54918.039512
# MALE     62541.169549  67658.692190   50384.646330  60568.684286  66412.103434

# %% [markdown]
# #### **Add More Categorical Variables**

# %%
print("Mean Income by Gender AND Marital Status")
multiple_grouping = df.groupby(['sex','marital', 'degree'])['income'].mean()
multiple_grouping
# Out:
# Mean Income by Gender AND Marital Status
# sex     marital        degree
# FEMALE  DIVORCED       BACHELOR           66000.005577
#                        GRADUATE           96371.271389
#                        HIGH SCHOOL        43432.538025
#                        JUNIOR COLLEGE     61842.908214
#                        LT HIGH SCHOOL     31164.281429
#         MARRIED        BACHELOR           80891.451250
#                        GRADUATE           98055.297368
#                        HIGH SCHOOL        51643.596856
#                        JUNIOR COLLEGE     58602.766563
#                        LT HIGH SCHOOL     30986.332988
#         NEVER MARRIED  BACHELOR           60106.639111
#                        GRADUATE           92939.027414
#                        HIGH SCHOOL        40957.714392
#                        JUNIOR COLLEGE     52592.065991
#                        LT HIGH SCHOOL     23940.274848
#         SEPARATED      BACHELOR           71857.841458
# ...

# %%
multiple_grouping = df.groupby(['sex','marital', 'degree'])['income'].mean().unstack()
multiple_grouping
# Out:
# degree                     BACHELOR       GRADUATE   HIGH SCHOOL  \
# sex    marital
# FEMALE DIVORCED        66000.005577   96371.271389  43432.538025
#        MARRIED         80891.451250   98055.297368  51643.596856
#        NEVER MARRIED   60106.639111   92939.027414  40957.714392
#        SEPARATED       71857.841458   81795.057917  47393.681389
#        WIDOWED         75323.098500   91993.304000  47278.949091
# MALE   DIVORCED        95417.128306  100899.502500  50543.274549
#        MARRIED         93975.251532  114803.052627  57758.371751
#        NEVER MARRIED   68866.653555   91416.020375  43045.164982
#        SEPARATED       86661.218750  116461.833125  52853.288500
#        WIDOWED        119482.447500  111472.776667  51566.073000
#
# degree                JUNIOR COLLEGE  LT HIGH SCHOOL
# sex    marital
# FEMALE DIVORCED         61842.908214    31164.281429
#        MARRIED          58602.766563    30986.332988
#        NEVER MARRIED    52592.065991    23940.274848
# ...

# %% [markdown]
# ### **Advanced Grouping and Multiple Aggregation**

# %%
summary = df.groupby('degree').agg({
    'income':['mean','median','std','count'],
    'age':'mean',
    'hrswrk' : 'mean'
})
summary
# Out:
#                        income                                        age  \
#                          mean      median           std count       mean
# degree
# BACHELOR         79394.490040   74575.610  33731.809663   566  39.909894
# GRADUATE        101312.290983  107071.185  35499.023670   234  41.461538
# HIGH SCHOOL      50326.169965   46500.255  26245.455646  1152  43.368924
# JUNIOR COLLEGE   63991.209984   56549.830  30427.157545   465  41.578495
# LT HIGH SCHOOL   33619.183349   29257.000  20586.434422   583  42.248714
#
#                    hrswrk
#                      mean
# degree
# BACHELOR        42.867491
# GRADUATE        43.615385
# HIGH SCHOOL     40.647569
# JUNIOR COLLEGE  40.406452
# LT HIGH SCHOOL  34.716981

# %% [markdown]
# ### **Mutating-Feature Engineering**

# %%
df.head()
# Out:
#     id     sex       degree    income        marital   age  height  weight  \
# 0  1.0    MALE  HIGH SCHOOL  26722.56  NEVER MARRIED  18.0    73.2    86.3
# 1  2.0    MALE  HIGH SCHOOL  36544.91        MARRIED  35.0    69.9    95.3
# 2  3.0  FEMALE  HIGH SCHOOL  59587.14       DIVORCED  28.0    70.1    60.9
# 3  4.0  FEMALE     GRADUATE  49586.54        MARRIED  43.0    61.9    76.0
# 4  5.0    MALE  HIGH SCHOOL  48899.47        MARRIED  48.0    65.8    58.9
#
#    hrswrk
# 0    35.0
# 1    47.0
# 2    16.0
# 3    44.0
# 4    44.0

# %%
median_income = df['income'].median()
median_income
# Out:
# 49586.54

# %%
df['Income_Category'] = np.where(df['income'] >= median_income,
                                 'High Income', 'Low Income')
df.head()
# Out:
#     id     sex       degree    income        marital   age  height  weight  \
# 0  1.0    MALE  HIGH SCHOOL  26722.56  NEVER MARRIED  18.0    73.2    86.3
# 1  2.0    MALE  HIGH SCHOOL  36544.91        MARRIED  35.0    69.9    95.3
# 2  3.0  FEMALE  HIGH SCHOOL  59587.14       DIVORCED  28.0    70.1    60.9
# 3  4.0  FEMALE     GRADUATE  49586.54        MARRIED  43.0    61.9    76.0
# 4  5.0    MALE  HIGH SCHOOL  48899.47        MARRIED  48.0    65.8    58.9
#
#    hrswrk Income_Category
# 0    35.0      Low Income
# 1    47.0      Low Income
# 2    16.0     High Income
# 3    44.0     High Income
# 4    44.0      Low Income

# %%
df['Income_Category'].value_counts()
# Out:
# Income_Category
# High Income    1617
# Low Income     1383
# Name: count, dtype: int64

# %% [markdown]
# #### **Verify the Grouping**

# %%
print("Verification - Median Income by Income Levels")
df.groupby('Income_Category')['income'].median()
# Out:
# Verification - Median Income by Income Levels
# Income_Category
# High Income    71801.05
# Low Income     31959.51
# Name: income, dtype: float64

# %% [markdown]
# #### **Alternative Verifcation Process**

# %%
df.groupby('Income_Category')['income'].describe()
# Out:
#                   count          mean           std       min       25%  \
# Income_Category
# High Income      1617.0  81755.685039  30507.829681  49586.54  55490.23
# Low Income       1383.0  31653.694201  10696.713196   3720.04  23167.80
#
#                       50%        75%          max
# Income_Category
# High Income      71801.05  102358.26  138753.5975
# Low Income       31959.51   40462.67   49576.4800

# %%
df.drop(columns = 'id').describe()
# Out:
#               income          age       height       weight       hrswrk
# count    3000.000000  3000.000000  3000.000000  3000.000000  3000.000000
# mean    58658.667263    42.072333    67.400367    76.315633    40.108000
# std     34324.748715    13.298623     3.640892    14.158958    11.627642
# min      3720.040000    18.000000    58.100000    45.000000    13.000000
# 25%     33681.547500    33.000000    64.600000    66.300000    34.000000
# 50%     49586.540000    42.000000    67.200000    75.700000    41.000000
# 75%     75710.367500    51.000000    70.100000    85.200000    48.000000
# max    138753.597500    78.000000    78.350000   113.550000    69.000000

# %% [markdown]
# ### **Frequency for Categorical Variables**

# %%
df.describe(include = ['object','category'])
# Out:
#            sex       degree  marital Income_Category
# count     3000         3000     3000            3000
# unique       2            5        5               2
# top     FEMALE  HIGH SCHOOL  MARRIED     High Income
# freq      1563         1152     1584            1617
