# %% [markdown]
# <div style='text-align:center;'>
#   <img src="CDAM.PNG" width="1200">
# </div>

# %% [markdown]
# <div style="text-align: center; font-weight: bold; font-size: 22px; color: #1a1a1a;">
#   <div style="color: #0B5394; font-size: 38px;">CENTER FOR DATA ANALYTICS AND MODELLING (CDAM)</div>
#   <div style="color: #38761D; font-size: 24px;">INTERMEDIATE PYTHON TRAINING: SESSION ONE; PYTHON ESSENTIAL FOR DATA SCIENCE</div>
#   <br>
#   <div style="color: #CC0000; font-size: 22px;">FACILITATOR:</div>
#   <div style="color: #000000; font-size: 20px;">VICTOR WANDERA LUMUMBA</div>
#   <div style="color: #3D85C6; font-size: 20px;">Chuka University, Kenya</div>
#   <br>
#   <div style="color: #6AA84F; font-size: 18px;">Date:</div>
#   <div style="color: #351C75; font-size: 18px;">May 21st, 2026</div>
# </div>

# %% [markdown]
# ## **Objective**
# This session aims to deepen participants’ foundational understanding of Python by introducing and reinforcing essential programming concepts and tools relevant for data science. Participants will move beyond the basics of variables and loops to explore how Python’s built-in capabilities can be leveraged for effective data handling and preprocessing.
# The focus is on five key areas critical for any data science or analytics workflow:
#
# 1.	**Advanced Data Types:** Understanding specialized Python containers such as namedtuple, defaultdict, and iterators from the itertools module allows for cleaner and more structured data management. These data types can enhance readability, performance, and reduce code complexity in real-world data processing tasks.
#
# 2.	**Functional Programming:** The ability to use lambda, map, filter, and reduce enables participants to write concise, elegant code that is efficient for data transformations. These tools are particularly valuable when performing repetitive or conditional tasks on data elements.
#
# 3.	**Comprehensions:** Mastering list, dictionary, and set comprehensions equips learners to transform and filter datasets compactly, a fundamental aspect of data wrangling and feature engineering.
#
# 4.	**File Input/Output (I/O):** Interacting with external files such as text, CSV, and JSON formats is a daily necessity in data science. This session covers best practices for reading, writing, and parsing data using Python’s standard libraries.
#
# 5.	**Jupyter Notebooks:** As the de facto environment for data science work, understanding how to efficiently use Jupyter Notebooks ensures that participants can document, debug, and present their analyses interactively.
#
# By the end of this session, participants will be equipped with the tools and techniques necessary to clean, transform, and manage data using core Python. These skills provide a strong foundation for more advanced data analysis and machine learning tasks in upcoming sessions.

# %% [markdown]
# ## Advanced Data Types
# ### 1. Collections
# Python’s `collections` module provides specialized container datatypes beyond built-in types like list, tuple, dict, and set.
#
# - `Counter`: For counting hashable objects
# - `defaultdict`: Like a dictionary, but provides a default value for the key that does not exist
# - `OrderedDict`: A dict that remembers insertion order (now built-in in modern Python)
# - `namedtuple`: Factory function for creating tuple subclasses with named fields
# - `deque`: A list-like container with fast appends and pops on either end

# %% [markdown]
# The code below uses `Counter` to count how many times each fruit appears in the list.
# It then prints a dictionary-like output showing the frequency of each fruit.

# %%
from collections import Counter, defaultdict, namedtuple, deque

# Counter example
cnt = Counter(['apple', 'orange', 'apple', 'pear', 'orange', 'banana'])
print(cnt)
# Out:
# Counter({'apple': 2, 'orange': 2, 'pear': 1, 'banana': 1})

# %% [markdown]
# The code below uses a `defaultdict` with integers to automatically initialize missing keys to zero and count how many times each item appears.
# It prints a dictionary showing the frequency of each fruit without needing to check if a key already exists.

# %%
# defaultdict example
d = defaultdict(int)
for item in ['apple', 'orange','mango','pineapple','banana']:
    d[item] += 3
print(d)
# Out:
# defaultdict(<class 'int'>, {'apple': 3, 'orange': 3, 'mango': 3, 'pineapple': 3, 'banana': 3})

# %% [markdown]
# This code creates a `namedtuple` called `Point` with fields `x` and `y`, allowing access to values by name instead of index.
# It then creates a point with coordinates `(1, 2)` and prints the `x` and `y` values.

# %%
# namedtuple example
Point = namedtuple('Point', ['x', 'y'])
p = Point(1, 2)
print(p.x, p.y)
# Out:
# 1 2

# %% [markdown]
# This code creates a `deque` with initial elements and adds an item to both the left and right ends.
# It then prints the updated deque, showing efficient insertion at both ends.

# %%
# deque example
q = deque([1, 2, 3])
q.appendleft(3)
q.append(4)
print(q)
# Out:
# deque([3, 1, 2, 3, 4])

# %% [markdown]
# ## Functional Programming
# Python supports functional programming paradigms using built-in functions like `map`, `filter`, `reduce`, and anonymous functions (`lambda`).

# %%
2**2
# Out:
# 4

# %% [markdown]
# * **Map:** This code uses `map()` to apply a function that squares each number in the list, producing a new list of squared values.
# * **Filter:** This code uses `filter()` to select only the even numbers from the list, returning a list that meets the condition.
# * **Reduce:** This code uses `reduce()` to multiply all the numbers in the list together, resulting in a single value that is the product of all elements.

# %%
from functools import reduce

# map example
nums = [1, 2, 3, 4, 5, 6, 7, 8, 10]
squares = list(map(lambda x: x**2, nums))
print("Squares:", squares)
# Out:
# Squares: [1, 4, 9, 16, 25, 36, 49, 64, 100]

# %%
# filter example
even = list(filter(lambda x: x % 2 == 0, nums))
print("Even Numbers:", even)
# Out:
# Even Numbers: [2, 4, 6, 8, 10]

# %%
# reduce example
product = reduce(lambda x, y: x * y, nums)
print("Product:", product)
product
# Out:
# Product: 403200
# 403200

# %%
1*2*3*4*5*6*7*8*10
# Out:
# 403200

# %% [markdown]
# ## Comprehensions
# Comprehensions provide a concise way to create lists, dictionaries, and sets from iterables.

# %% [markdown]
# * **List comprehension:** This code creates a list containing the squares of numbers from 0 to 9 in a concise and readable way.
# * **Dictionary comprehension:** This code creates a dictionary where each key is a number and its value is the square of that number.
# * **Set comprehension:** This code creates a set of squared values, automatically removing any duplicate results.

# %%
# List comprehension
squares = [x**2 for x in range(10)]
print(squares)

# Dictionary comprehension
square_dict = {x: x**2 for x in range(5)}
print(square_dict)

# Set comprehension
unique_squares = {x**2 for x in [1, 2, 3]}
print(unique_squares)
# Out:
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]
# {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
# {1, 4, 9}

# %% [markdown]
# ## File I/O
# Python makes it easy to read and write files such as text, CSV, and JSON.

# %% [markdown]
# * **Text file I/O:** This code writes a short message to a text file and then reads the file contents back and prints them.

# %%
# Writing and reading a text file
with open("example.txt", "w") as f:
    f.write("Hello, world!\nPython file I/O\nCreated and Saved.")

with open("example.txt", "r") as f:
    print(f.read())
# Out:
# Hello, world!
# Python file I/O
# Created and Saved.

# %% [markdown]
# * **JSON handling:** This code saves a Python dictionary to a JSON file and then loads it back into Python, preserving the data structure.

# %%
import json

# %%
# JSON
import json
data = {'name': 'Alice', 'age': 25, 'city': 'Nairobi'}
with open('data.json', 'w') as f:
    json.dump(data, f)

with open('data.json', 'r') as f:
    loaded = json.load(f)
    print(loaded)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Nairobi'}

# %% [markdown]
# ### Read the CSV File

# %% [markdown]
# This code imports the pandas library, reads a CSV file named **GSSsubset.csv** into a DataFrame, and stores it in `df`.
# The `df.head()` function then displays the first five rows of the dataset to give a quick preview of the data.

# %%
import pandas as pd
df = pd.read_csv("GSSsubset.csv")
df.head()
# Out:
#    id     sex       degree    income   marital   age  height  weight  hrswrk
# 0   1    MALE     BACHELOR  60967.50  DIVORCED  53.0    72.0   190.0    60.0
# 1   2  FEMALE     BACHELOR  60967.50   MARRIED  26.0    60.0    97.0    40.0
# 2   4  FEMALE     BACHELOR  10161.25   MARRIED  56.0    68.0   160.0    20.0
# 3  14  FEMALE  HIGH SCHOOL  17551.25   MARRIED  40.0    65.0   156.0    37.0
# 4  16    MALE  HIGH SCHOOL  17551.25   MARRIED  56.0     NaN   210.0     6.0

# %% [markdown]
# ## Jupyter Notebooks
# Jupyter Notebooks provide an interactive environment for writing and running Python code, making it ideal for data science. Best practices include:
#
# - Use Markdown cells to document code
# - Break long notebooks into sections with headers
# - Avoid running long or destructive operations without checks
# - Keep output clean and reproducible
#
# ## Practical Lab: Data Cleaning Without Libraries
# **Objective:** Use core Python to clean a mock dataset loaded from a text file, including stripping whitespace, filtering missing entries, and computing basic stats.

# %%
# Sample data (normally loaded from file)
data = {
    "Name": ['Alice', 'Bob', 'Charlie', 'Diana','Kevin', 'Mary'],
    "Age": [24, 18, 21, 22, 20, 17],
    "Weight": [65, 67, 76, 87, 67, 45],
    "Height": [123, 143, 155, 176, 133, 145],
    "Gender": ["Female","Male","Male","Female","Male","Female"],
    "Income": [20000, 25000, 30000, 45000, 35000,50000],
    "Occupation": ["Teacher","Nurse","Farmer","Driver","Farmer","Police Officer"]
}
data
# Out:
# {'Name': ['Alice', 'Bob', 'Charlie', 'Diana', 'Kevin', 'Mary'],
#  'Age': [24, 18, 21, 22, 20, 17],
#  'Weight': [65, 67, 76, 87, 67, 45],
#  'Height': [123, 143, 155, 176, 133, 145],
#  'Gender': ['Female', 'Male', 'Male', 'Female', 'Male', 'Female'],
#  'Income': [20000, 25000, 30000, 45000, 35000, 50000],
#  'Occupation': ['Teacher',
#   'Nurse',
#   'Farmer',
#   'Driver',
#   'Farmer',
#   'Police Officer']}

# %% [markdown]
# ### **Convert the Dictionary to a Data Frame**

# %%
import pandas as pd
data = pd.DataFrame(data)
data.head()
# Out:
#       Name  Age  Weight  Height  Gender  Income Occupation
# 0    Alice   24      65     123  Female   20000    Teacher
# 1      Bob   18      67     143    Male   25000      Nurse
# 2  Charlie   21      76     155    Male   30000     Farmer
# 3    Diana   22      87     176  Female   45000     Driver
# 4    Kevin   20      67     133    Male   35000     Farmer

# %% [markdown]
# ### **Write the Data Frame to the Local Directory**

# %%
data.to_csv("Created_data.csv", index = False)

# %% [markdown]
# ```python
# header = [col.strip() for col in data[0].split(',')]
# ```
#
# * Take the first row of `data` (the header row).
# * Split the string by commas to separate column names.
# * Use `.strip()` to remove extra spaces from each column name.
# * Store the clean column names in the list `header`.
#
# ```python
# records = []
# ```
#
# * Create an empty list `records` to store the cleaned data rows as dictionaries.
#
# ```python
# for row in data[1:]:
# ```
#
# * Loop over all rows in `data` **except the header** (i.e., from the second row onward).
#
# ```python
# fields = [field.strip() for field in row.split(',')]
# ```
#
# * Split the current row string by commas to get individual field values.
# * Strip leading and trailing spaces from each field.
# * Store the cleaned values in the list `fields`.
#
# ```python
# if all(fields):
# ```
#
# * Check if **all fields have a value** (i.e., no empty or missing data).
# * Only proceed if the row is complete.
#
# ```python
# records.append(dict(zip(header, fields)))
# ```
#
# * Pair each field value with its corresponding column name using `zip(header, fields)`.
# * Convert the zipped pairs into a dictionary.
# * Append the dictionary to the `records` list.
#
# ```python
# print("Cleaned Records:")
# for rec in records:
#     print(rec)
# ```
#
# * Print the title `"Cleaned Records:"`.
# * Loop through each dictionary in `records` and print it to show the cleaned data.

# %%
# Clean and process data
header = [col.strip() for col in data[0].split(',')]
records = []
for row in data[1:]:
    fields = [field.strip() for field in row.split(',')]
    if all(fields):
        records.append(dict(zip(header, fields)))

print("Cleaned Records:")
for rec in records:
    print(rec)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 2
#       1 # Clean and process data
# ...

# %% [markdown]
# Finally, the program extracts the Score values from the cleaned records, converts them to integers, computes the average score, and prints the result.

# %%
# Compute average score
scores = [int(rec['Score']) for rec in records]
avg_score = sum(scores) / len(scores)
print("Average Score:", avg_score)

# %%
#pip install mysql-connector-python

# %%
import mysql.connector
import pandas as pd

# Connect to MySQL database
connection = mysql.connector.connect(
    host='localhost',
    port=3306,
    user='root',
    password='1992',
    database='mydb'
)

# SQL query
query = "SELECT * FROM orders"

# Read table into pandas DataFrame
df = pd.read_sql(query, connection)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_6296\2210268416.py:17: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql(query, connection)

# %%
# Display first rows
df.head()
# Out:
#    Row ID         OrderID   OrderDate    ShipDate        ShipMode CustomerID  \
# 0       1  CA-2017-152156  2017-11-08  2017-11-11    Second Class   CG-12520
# 1       2  CA-2017-152156  2017-11-08  2017-11-11    Second Class   CG-12520
# 2       3  CA-2017-138688  2017-06-12  2017-06-16    Second Class   DV-13045
# 3       4  US-2016-108966  2016-10-11  2016-10-18  Standard Class   SO-20335
# 4       5  US-2016-108966  2016-10-11  2016-10-18  Standard Class   SO-20335
#
#       CustomerName    Segment        Country             City  ... PostalCode  \
# 0      Claire Gute   Consumer  United States        Henderson  ...      42420
# 1      Claire Gute   Consumer  United States        Henderson  ...      42420
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...      90036
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...      33311
#
# ...

# %%
# Close connection
connection.close()
